# %%
from sympy import *
from sympy.plotting import plot
from sympy.geometry import *

init_printing()
x, y, z = symbols("x y z")

# %%
z = Point(2, 2)
plot(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 2>()
#       1 z = Point(2, 2)
# ----> 2 plot(z)
#
# File /home/linuxbrew/.linuxbrew/opt/python@3.10/lib/python3.10/site-packages/sympy/plotting/plot.py:1869, in plot(show, *args, **kwargs)
#    1867 series = []
#    1868 plot_expr = check_arguments(args, 1, 1)
# -> 1869 series = [LineOver1DRangeSeries(*arg, **kwargs) for arg in plot_expr]
#    1871 plots = Plot(*series, **kwargs)
#    1872 if show:
#
# TypeError: 'NoneType' object is not iterable

# %%
plot(abs(x - 10) + 2, (x, -100, 100), xlim=(0, 20), ylim=(0, 20))

# %%
plot(y)

# %%
z
# Out:
#  2
# x

# %%
# https://docs.sympy.org/latest/modules/plotting.html
plot(x + cos(x), x + 4, 10 * sqrt(x), (x, -20, 20))

# %%
z
# Out:
#  2
# x

# %%
y = x**2

# %%
plot(y + 5)
